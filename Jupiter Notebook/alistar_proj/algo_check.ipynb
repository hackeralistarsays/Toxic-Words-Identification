# %%
#import nltk package
import nltk
import pyscreenshot as ImageGrab
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from tkinter import messagebox
from multiprocessing import Process



exception = (stopwords.words() [620:680])

sentence = "SHE WAS KILLING HER MURDERED THEM AND HACKED THEIR HEAD OFF, FUCKER DID IT IN COLD BLOOD IN THE DARKNESS..."
individual = sentence.split()
lower = sentence.lower()

stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(lower) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
pop = messagebox.showinfo("DANGEROUS CONTENTS DETECTED", filtered_sentence)  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
        
print("The sentence in lowercase") 
print("-----------------------------")
print(word_tokens) 
print("\n")
print("The sentence without stopwords") 
print("-----------------------------")
print(filtered_sentence) 
print("\n")
print("Some of the tokens omitted")
print("-----------------------------")
print(exception)
print("-------------------------------------------------------------------------------------------------------------------------------")



#Defining method functions

def screenshot():
     im=ImageGrab.grab()

def func2():
     pop

if __name__=='__main__':
     p1 = Process(target = screenshot)
     p1.start()
     p2 = Process(target = func2)
     p2.start()
    


#stemming using PorterStemmer algorithm
potter = PorterStemmer()
lan = LancasterStemmer()

i = len(filtered_sentence)
m = int(0)

while m < i:
    q = filtered_sentence[m]
    print(potter.stem(q))
    m = m + 1 
   
print("------------")
if ("kill" in q) and ("blood" in q) and ("hack" in q) and ("murder" in q) and ("fuck" in q):
   
    pop
    




elif ("pain" in q) or ("hurt" in q):
    print("warning")

else:
    print("try again")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-2-84ea44eb80ea> in <module>
#      21
#      22 filtered_sentence = [w for w in word_tokens if not w in stop_words]
# ---> 23 pop = messagebox.showinfo("DANGEROUS CONTENTS DETECTED", filtered_sentence)
#      24 filtered_sentence = []
#      25
#
# ~/anaconda3/lib/python3.7/tkinter/messagebox.py in showinfo(title, message, **options)
#      81 def showinfo(title=None, message=None, **options):
#      82     "Show an info message"
# ---> 83     return _show(title, message, INFO, OK, **options)
#      84
#      85 def showwarning(title=None, message=None, **options):
#
# ~/anaconda3/lib/python3.7/tkinter/messagebox.py in _show(title, message, _icon, _type, **options)
#      70     if title:   options["title"] = title
#      71     if message: options["message"] = message
# ---> 72     res = Message(**options).show()
# ...
